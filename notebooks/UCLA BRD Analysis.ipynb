# %%
import pandas as pd
import numpy as nm

# %% [markdown]
# # UCLA - LoPukci Bankruptcy Research Database

# %%
brd_location = "UCLA-LoPucki Bankruptcy Research Database.csv"
brd = pd.read_csv(brd_location, encoding='cp1252')
brd.sort('XYearFiled', ascending=False)
# Out:
# <div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>XNameCorp</th>
#       <th>AfterEmerging</th>
#       <th>Assets1Before</th>
#       <th>Assets2Before</th>
#       <th>Assets3Before</th>
#       <th>AssetsBefore</th>
#       <th>AssetsCurrDollar</th>
#       <th>AssetsEmerging</th>
#       <th>AssetsPetCurrDollar</th>
#       <th>AssetsPetition</th>
#       <th>...</th>
#       <th>XPrepackaged</th>
#       <th>XShop</th>
#       <th>XSICMajGroup</th>
#       <th>XTortCause</th>
#       <th>XVoluntary</th>
#       <th>XYearDisposed</th>
#       <th>XYearEmerged</th>
#       <th>XYearFiled</th>
#       <th>YearConfirmed</th>
#       <th>YearsToRefile</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0  </th>
#       <td>                            1st Centennial Bancorp</td>
# ...

# %% [markdown]
# # Fields used in the BRD database

# %%
list(brd.columns.values)
# Out:
# ['XNameCorp',
#  'AfterEmerging',
#  'Assets1Before',
#  'Assets2Before',
#  'Assets3Before',
#  'AssetsBefore',
#  'AssetsCurrDollar',
#  'AssetsEmerging',
#  'AssetsPetCurrDollar',
#  'AssetsPetition',
#  'BondISIN',
#  'BondPriceDisp',
#  'BondPriceFile',
#  'BondPriceMoveDuring',
#  'CaseNum',
#  'CaseNumRefile',
#  'CaseNumTransfer',
#  'CeoFiling',
#  'CeoNotes',
#  'CeoSaleExit',
#  'CikBefore',
#  'CikEmerging',
#  'CityChange',
#  'CityDisposed',
#  'CityRefile',
#  'ClaimsAgentPetition',
#  'ClaimsSecDiscloState',
#  'ClaimsUnsec',
#  'CommCred',
#  'CommCredAttyCol',
#  'CommCredAttyRes',
#  'CommCredAttySubstit',
#  'CommEquity',
#  'CommEquityAttyCol',
#  'CommEquityAttyRes',
#  'CommEquityAttySubstit',
#  'CommEquityName',
#  'CommRetirees',
#  'CommRetireesName',
#  'CommRetireesRequest',
#  'CommonName',
#  'CPIndexAtConf',
#  'CPIndexAtFiling',
#  'Cusip6',
#  'Cusip9',
#  'Date10k1Before',
#  'Date10k2Before',
#  'Date10k3Before',
#  'Date10kBefore',
# ...
